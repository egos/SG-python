# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Installation" data-toc-modified-id="Installation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Installation</a></span><ul class="toc-item"><li><span><a href="#anaconda" data-toc-modified-id="anaconda-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>anaconda</a></span></li><li><span><a href="#jupyter--nbextention-&amp;-option" data-toc-modified-id="jupyter--nbextention-&amp;-option-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>jupyter  nbextention &amp; option</a></span></li></ul></li><li><span><a href="#Hello-World" data-toc-modified-id="Hello-World-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Hello World</a></span><ul class="toc-item"><li><span><a href="#print" data-toc-modified-id="print-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>print</a></span></li><li><span><a href="#python" data-toc-modified-id="python-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>python</a></span></li></ul></li><li><span><a href="#Plan" data-toc-modified-id="Plan-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Plan</a></span><ul class="toc-item"><li><span><a href="#Plan-formation" data-toc-modified-id="Plan-formation-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Plan formation</a></span></li><li><span><a href="#Pause-algo-ou-live-coding" data-toc-modified-id="Pause-algo-ou-live-coding-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Pause algo ou live coding</a></span></li></ul></li><li><span><a href="#IMPORT" data-toc-modified-id="IMPORT-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>IMPORT</a></span></li><li><span><a href="#Python-/-Pandas" data-toc-modified-id="Python-/-Pandas-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Python / Pandas</a></span><ul class="toc-item"><li><span><a href="#BigPicture" data-toc-modified-id="BigPicture-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>BigPicture</a></span></li><li><span><a href="#Liens-utile-/-ressources" data-toc-modified-id="Liens-utile-/-ressources-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Liens utile / ressources</a></span><ul class="toc-item"><li><span><a href="#Doc-python-/-pandas" data-toc-modified-id="Doc-python-/-pandas-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Doc python / pandas</a></span></li><li><span><a href="#Doc-Maxx" data-toc-modified-id="Doc-Maxx-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Doc Maxx</a></span></li></ul></li><li><span><a href="#basic-Python" data-toc-modified-id="basic-Python-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>basic Python</a></span></li><li><span><a href="#Basic-Pandas" data-toc-modified-id="Basic-Pandas-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Basic Pandas</a></span></li><li><span><a href="#Utils" data-toc-modified-id="Utils-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Utils</a></span><ul class="toc-item"><li><span><a href="#tqdm" data-toc-modified-id="tqdm-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>tqdm</a></span></li><li><span><a href="#time" data-toc-modified-id="time-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>time</a></span></li><li><span><a href="#Glob" data-toc-modified-id="Glob-5.5.3"><span class="toc-item-num">5.5.3&nbsp;&nbsp;</span>Glob</a></span></li></ul></li></ul></li><li><span><a href="#Data-manipulation" data-toc-modified-id="Data-manipulation-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data manipulation</a></span><ul class="toc-item"><li><span><a href="#Load" data-toc-modified-id="Load-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#Colonne-not-Null" data-toc-modified-id="Colonne-not-Null-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Colonne not Null</a></span></li><li><span><a href="#Enrichissement-I-(docstring):-schema" data-toc-modified-id="Enrichissement-I-(docstring):-schema-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Enrichissement I (docstring): schema</a></span></li><li><span><a href="#Selec-colonnes" data-toc-modified-id="Selec-colonnes-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Selec colonnes</a></span></li><li><span><a href="#format-data" data-toc-modified-id="format-data-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>format data</a></span></li><li><span><a href="#Enrichissement-II-(merge):-region" data-toc-modified-id="Enrichissement-II-(merge):-region-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Enrichissement II (merge): region</a></span><ul class="toc-item"><li><span><a href="#Ajout-Paris" data-toc-modified-id="Ajout-Paris-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>Ajout Paris</a></span></li><li><span><a href="#correction-Code_departement" data-toc-modified-id="correction-Code_departement-6.6.2"><span class="toc-item-num">6.6.2&nbsp;&nbsp;</span>correction Code_departement</a></span></li></ul></li></ul></li><li><span><a href="#export-data" data-toc-modified-id="export-data-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>export data</a></span><ul class="toc-item"><li><span><a href="#json" data-toc-modified-id="json-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>json</a></span></li><li><span><a href="#Clipboard" data-toc-modified-id="Clipboard-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Clipboard</a></span></li><li><span><a href="#Csv-excel-..." data-toc-modified-id="Csv-excel-...-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Csv excel ...</a></span></li><li><span><a href="#ex-:-Row-graph-(~Maxx)" data-toc-modified-id="ex-:-Row-graph-(~Maxx)-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>ex : Row graph (~Maxx)</a></span></li></ul></li><li><span><a href="#Analyse" data-toc-modified-id="Analyse-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Analyse</a></span><ul class="toc-item"><li><span><a href="#Groupby" data-toc-modified-id="Groupby-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Groupby</a></span></li><li><span><a href="#Describe" data-toc-modified-id="Describe-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Describe</a></span></li><li><span><a href="#Categories" data-toc-modified-id="Categories-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Categories</a></span></li><li><span><a href="#stack-unstack" data-toc-modified-id="stack-unstack-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>stack unstack</a></span></li><li><span><a href="#pivot-table" data-toc-modified-id="pivot-table-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>pivot table</a></span></li><li><span><a href="#percentiles" data-toc-modified-id="percentiles-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>percentiles</a></span></li><li><span><a href="#TimeSerie" data-toc-modified-id="TimeSerie-8.7"><span class="toc-item-num">8.7&nbsp;&nbsp;</span>TimeSerie</a></span><ul class="toc-item"><li><span><a href="#to-Date-time" data-toc-modified-id="to-Date-time-8.7.1"><span class="toc-item-num">8.7.1&nbsp;&nbsp;</span>to Date time</a></span></li><li><span><a href="#Manip-dt" data-toc-modified-id="Manip-dt-8.7.2"><span class="toc-item-num">8.7.2&nbsp;&nbsp;</span>Manip dt</a></span></li><li><span><a href="#rolling" data-toc-modified-id="rolling-8.7.3"><span class="toc-item-num">8.7.3&nbsp;&nbsp;</span>rolling</a></span></li></ul></li></ul></li><li><span><a href="#Export-MAXX" data-toc-modified-id="Export-MAXX-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Export MAXX</a></span><ul class="toc-item"><li><span><a href="#lambda" data-toc-modified-id="lambda-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>lambda</a></span></li><li><span><a href="#function" data-toc-modified-id="function-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>function</a></span></li><li><span><a href="#swagger" data-toc-modified-id="swagger-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>swagger</a></span></li><li><span><a href="#widget" data-toc-modified-id="widget-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>widget</a></span></li></ul></li><li><span><a href="#Pycharm" data-toc-modified-id="Pycharm-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Pycharm</a></span><ul class="toc-item"><li><span><a href="#presentation" data-toc-modified-id="presentation-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>presentation</a></span></li><li><span><a href="#export-function-to-pycharm" data-toc-modified-id="export-function-to-pycharm-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>export function to pycharm</a></span></li></ul></li><li><span><a href="#refactorer" data-toc-modified-id="refactorer-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>refactorer</a></span><ul class="toc-item"><li><span><a href="#class" data-toc-modified-id="class-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>class</a></span></li><li><span><a href="#module" data-toc-modified-id="module-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>module</a></span></li><li><span><a href="#TP" data-toc-modified-id="TP-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>TP</a></span></li></ul></li><li><span><a href="#dev" data-toc-modified-id="dev-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>dev</a></span><ul class="toc-item"><li><span><a href="#pytest" data-toc-modified-id="pytest-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>pytest</a></span></li><li><span><a href="#git" data-toc-modified-id="git-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>git</a></span></li></ul></li><li><span><a href="#Drill-Down" data-toc-modified-id="Drill-Down-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Drill Down</a></span></li><li><span><a href="#Bonus" data-toc-modified-id="Bonus-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Bonus</a></span><ul class="toc-item"><li><span><a href="#Scrap-?" data-toc-modified-id="Scrap-?-14.1"><span class="toc-item-num">14.1&nbsp;&nbsp;</span>Scrap ?</a></span></li><li><span><a href="#GeoLoc" data-toc-modified-id="GeoLoc-14.2"><span class="toc-item-num">14.2&nbsp;&nbsp;</span>GeoLoc</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Installation

# %% [markdown]
# ## anaconda

# %% [markdown]
# ## jupyter  nbextention & option

# %%
# pour permettre d'afficher plusieurs df en meme temps 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70%! important; }</style>"))
# Out:
# <style>.container { width:70%! important; }</style>

# %% [markdown]
# # Hello World

# %% [markdown]
# ## print

# %%
txt = 'hello world'
print (txt)
# Out:
# hello world

# %% [markdown]
# ## python

# %%
txt.upper()
# Out:
# 'HELLO WORLD'

# %%
newtxt = ''.join([x.upper() if random.randint(0,1)==1 else x for x in txt ])
print(newtxt)
# Out:
# HeLlO WORLd

# %%
for i in range(3):
    newtxt = ''.join([x.upper() if random.randint(0,1)==1 else x for x in txt ])
    print(newtxt)
# Out:
# HEllo WORld
# HEllO wORLd
# hEllo wORld

# %%
import random
data = {}
for i in range(100):
    newtxt = ''.join([x.upper() if random.randint(0,1)==1 else x for x in txt ])
    data[newtxt] = random.randint(1,100)

# %%
from wordcloud import WordCloud
wc = WordCloud(width=800, height=400, max_words=200).generate_from_frequencies(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 20))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %% [markdown]
# # Plan

# %% [markdown]
# ## Plan formation

# %% [markdown]
# ## Pause algo ou live coding

# %% [markdown]
# excercice pour creer un json a partir des données brut de ce nootebook = table of content

# %%
import json
Name = "Python.ipynb"
#Name = 'Mardown.ipynb'
with open(Name, "r") as file:
    data = json.load(file)

# %%
L = []
D = {}
i = [0,0,0]
for x in data['cells']:
    if x['cell_type'] == 'markdown':
        cible = x['source'][0]
        cible2 = cible.replace('#' ,'')
        if  '###' in cible:
            title3 = cible2
            D[title1][title2][title3]  =  {}
        elif '##' in cible:
            title2 = cible2
            D[title1][title2] = {}
        elif '#' in cible:
            title1 = cible2
            D[title1] = {}

# %% [raw]
# print (json.dumps(D,sort_keys=False, indent=4))

# %%
df = pd.DataFrame(D).stack().reset_index()
df['level_2'] = df.iloc[:,-1].apply(lambda x : ' :: '.join(list(x.keys())) if x else np.NAN).fillna('').astype(str)
df = df.drop([0],1)
dfsave = df.level_1.copy()
df.level_1 = df.level_0.copy()
df.level_0 = dfsave
df = df.set_index (['level_0', 'level_1'])
df.to_excel('Plan_.xlsx')
df
# Out:
#                                                                                                level_2
# level_0            level_1
#  Installation       anaconda
#                     jupyter  nbextention & option
#  Hello World        print
#                     python
#  Plan               Pause algo
#  Python / Pandas    BigPicture
#                     Liens utile / ressources                          Doc python / pandas ::  Doc Maxx
#                     basic Python
#                     Basic Pandas
#                     Utils                                                       tqdm ::  time ::  Glob
#  Data manipulation  Load
#                     Trie
#                     Selec colonnes non null
#                     Enrichissement I (docstring): schema
#                     Selec colonnes
#                     format data
#                     Enrichissement II (merge): region      Ajout Paris ::  correction Code_departement
#  export data        json
# ...

# %% [markdown]
# df  = pd.DataFrame.from_dict({(i,j): D[i][j]
#                            for i in D.keys()
#                            for j in D[i].keys() if D[i] else 0},
#                        orient='index').stack().to_frame().reset_index().drop([0],1)
# df

# %% [markdown]
# for i in D.keys():
#     print(i)
#     if D[i] :
#         for j in D[i].keys():
#             print (i,j)
#     else :

# %% [markdown]
# # IMPORT

# %%
import urllib.parse

import json
import pandas as pd
import time
import numpy as np
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import time
from datetime import datetime

#from pymongo import MongoClient
import glob, os

# %matplotlib inline

# %%
# quel galere ce truc ca depend des version anaconda / jupyter il faut le regler 
# %config Completer.use_jedi = False

# %% [markdown]
# # Python / Pandas

# %% [markdown]
# ## BigPicture

# %%
from IPython.display import Image
Image("2020-02-13_1701.png", width=700)

# %%
Image("2020-02-13_1705.png", width=700)

# %% [markdown]
# ## Liens utile / ressources

# %% [markdown]
# ### Doc python / pandas

# %% [markdown]
# the master
# https://wesmckinney.com/pages/about.html

# %% [markdown]
# les cours
# https://github.com/wesm/pydata-book

# %% [markdown]
# incontournable  : http://sametmax.com/ce-quil-faut-savoir-en-python/

# %% [markdown]
# ### Doc Maxx

# %% [markdown]
# ## basic Python

# %%
# Listes
# 1) Créer une liste d'entiers d'au moins 10 éléments et afficher la taille de la liste
l = [5,8,9,5,4,9,3,9,3,0,5,3]
print(len(l))

# 2) Afficher du 3eme au 5eme élément de la liste (en une ligne de code)
print(l[2:5])

# 3) Ajouter un nombre réel à cette liste et afficher la liste
l.append(236.6)
print(l)

# 4) Afficher la plus faible valeur de la liste (Sans modifier la liste)
print(sorted(l)[0])

# String
s = "This is a totaly random sentence."
print(s)

# 1) Retirer le mot 'totaly' de la phrase et afficher la nouvelle phrase
s = s.replace('totaly ', '')
print(s)

# 2) Créer une liste contenant tout les mots de la phrase (sans la ponctuation) et l'afficher
l = s[:-1].split(' ')
print(l)

# Dictionnaries and Loop
d = {'a': 5, 'g':8.89, 9: ['a', 2, 3], 7: "hello"}

# 1) afficher la liste des clés
print(d.keys())

# 2) Utiliser une boucle pour afficher une phrase contenant la clé 
#    et la valeur correspondantes pour tous les éléments du dictionnaire
for k, v in d.items():
    print("La clé {} contient la valeur {}".format(k, v))
    
# 3) Dans la boucle précédante, ajouter une phrase spécifique lorsque la valeur 5 est trouvée
for k, v in d.items():
    if v == 5:
        print("C'est la valeur {} pour la clé {}!".format(v, k))
    else:
        print("La clé {} contient la valeur {}".format(k, v))

# %%
a = 2 

a

b=3

a*b

List = [2,3,5]

Sum = 0
for i in List:
    Sum = Sum + i

Sum

list('abc')

Dict = {'a': 2, 'b': 3, 'c': 5}

for key, value in Dict.items():
    print (key, value)

Sum = 0
for key, value in Dict.items():
    Sum = Sum + value
Sum

# %%
dict(zip(list('abc'), [2,3,5]))

sum([v for k,v in Dict.items()])

# %% [markdown]
# ## Basic Pandas

# %% [markdown]
# ## Utils

# %% [markdown]
# ### tqdm

# %%
import tqdm
import time

for i in tqdm.tqdm(range(100)):
    time.sleep(0.01)

# %% [markdown]
# ### time

# %%
import time
t = time.time()

time.strftime('%Y-%m-%d %H:%M %Z', time.localtime(t))
# Out:
# '2020-02-26 21:19 Paris, Madrid'

# %%
import datetime
datetime.datetime.utcnow()
# Out:
# datetime.datetime(2020, 2, 26, 16, 13, 16, 21864)

# %% [markdown]
# ### Glob

# %%
import glob
path = 'img/*.*'
glob.glob(path)
# Out:
# ['img\\2020-02-13_1701.png',
#  'img\\2020-02-13_1705.png',
#  'img\\NotebookShortcut.png']

# %% [markdown]
# # Data manipulation

# %% [markdown]
# https://www.data.gouv.fr/fr/datasets/demandes-de-valeurs-foncieres-geolocalisees/

# %% [markdown]
# ## Load

# %%
path = 'Data\*.txt'
Filelist = [p for p in glob.glob(path)]
Filelist
# Out:
# ['Data\\valeursfoncieres-2018.txt', 'Data\\valeursfoncieres-2019.txt']

# %%
# %%time
file = Filelist[1]
df = pd.read_csv(file, sep="|", error_bad_lines=False)
# Out:
# <string>:2: DtypeWarning: Columns (14,18,23,24,26,28,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
# Wall time: 4.43 s

# %%
df.shape
# Out:
# (1017154, 43)

# %%
df.head()
# Out:
#    Code service CH  Reference document  1 Articles CGI  2 Articles CGI  \
# 0              NaN                 NaN             NaN             NaN
# 1              NaN                 NaN             NaN             NaN
# 2              NaN                 NaN             NaN             NaN
# 3              NaN                 NaN             NaN             NaN
# 4              NaN                 NaN             NaN             NaN
#
#    3 Articles CGI  4 Articles CGI  5 Articles CGI  No disposition  \
# 0             NaN             NaN             NaN               1
# 1             NaN             NaN             NaN               1
# 2             NaN             NaN             NaN               1
# 3             NaN             NaN             NaN               1
# 4             NaN             NaN             NaN               1
#
#   Date mutation Nature mutation  ... Surface Carrez du 5eme lot  \
# 0    11/01/2019           Vente  ...                        NaN
# ...

# %%
df.to_pickle('df')

# %% [markdown]
# ## Colonne not Null

# %%
# %%time
df = pd.read_pickle('df')
# Out:
# Wall time: 2.73 s

# %%
a = (df.isnull().sum()/df.shape[0]).round(2)

# %% [markdown]
# df.columns

# %%
a.plot.barh(figsize = (10,10))

# %% [markdown]
# pd.set_option('display.max_colwidth', -1)

# %%
dfc = (df.isnull().sum()/df.shape[0]).round(2)

# %%
dfc.index = dfc.index.str.replace(' ','_')

# %%
dfc.plot.barh(figsize = (10,10))

# %%
df = df.dropna(axis=1,how='all')
df.shape
# Out:
# (1017154, 35)

# %%
df.columns = dfc.index
df = df[dfc[dfc< 0.9].index]
df.shape
# Out:
# (1017154, 22)

# %%
df.to_pickle('df')

# %%
df.head()
# Out:
#    No_disposition Date_mutation Nature_mutation Valeur_fonciere  No_voie  \
# 0  1               11/01/2019    Vente           84000,00        552.0
# 1  1               11/01/2019    Vente           84000,00        552.0
# 2  1               08/02/2019    Vente           210000,00       5189.0
# 3  1               08/02/2019    Vente           210000,00       5189.0
# 4  1               04/04/2019    Vente           36000,00        40.0
#
#   Type_de_voie Code_voie            Voie  Code_postal  \
# 0  AV           0260      DE LYON         1960.0
# 1  AV           0260      DE LYON         1960.0
# 2  NaN          B041      LE METRILLOT    1250.0
# 3  NaN          B041      LE METRILLOT    1250.0
# 4  PL           0090      DE LA FONTAINE  1560.0
#
#                       Commune  ... Section  No_plan 1er_lot  Nombre_de_lots  \
# 0  PERONNAS                    ...  AD      226      44      1
# 1  PERONNAS                    ...  AD      226      1       2
# ...

# %% [markdown]
# ## Enrichissement I (docstring): schema

# %%
txt = '''id_mutation : Identifiant de mutation (non stable, sert à grouper les lignes)
    date_mutation : Date de la mutation au format ISO-8601 (YYYY-MM-DD)
    numero_disposition : Numéro de disposition
    valeur_fonciere : Valeur foncière (séparateur décimal = point)
    adresse_numero : Numéro de l'adresse
    adresse_suffixe : Suffixe du numéro de l'adresse (B, T, Q)
    adresse_code_voie : Code FANTOIR de la voie (4 caractères)
    adresse_nom_voie : Nom de la voie de l'adresse
    code_postal : Code postal (5 caractères)
    code_commune : Code commune INSEE (5 caractères)
    nom_commune : Nom de la commune (accentué)
    ancien_code_commune : Ancien code commune INSEE (si différent lors de la mutation)
    ancien_nom_commune : Ancien nom de la commune (si différent lors de la mutation)
    code_departement : Code département INSEE (2 ou 3 caractères)
    id_parcelle : Identifiant de parcelle (14 caractères)
    ancien_id_parcelle : Ancien identifiant de parcelle (si différent lors de la mutation)
    numero_volume : Numéro de volume
    lot_1_numero : Numéro du lot 1
    lot_1_surface_carrez : Surface Carrez du lot 1
    lot_2_numero : Numéro du lot 2
    lot_2_surface_carrez : Surface Carrez du lot 2
    lot_3_numero : Numéro du lot 3
    lot_3_surface_carrez : Surface Carrez du lot 3
    lot_4_numero : Numéro du lot 4
    lot_4_surface_carrez : Surface Carrez du lot 4
    lot_5_numero : Numéro du lot 5
    lot_5_surface_carrez : Surface Carrez du lot 5
    nombre_lots : Nombre de lots
    code_type_local : Code de type de local
    type_local : Libellé du type de local
    surface_reelle_bati : Surface réelle du bâti
    nombre_pieces_principales : Nombre de pièces principales
    code_nature_culture : Code de nature de culture
    nature_culture : Libellé de nature de culture
    code_nature_culture_speciale : Code de nature de culture spéciale
    nature_culture_speciale : Libellé de nature de culture spéciale
    surface_terrain : Surface du terrain
    longitude : Longitude du centre de la parcelle concernée (WGS-84)
    latitude : Latitude du centre de la parcelle concernée (WGS-84)'''

# %%
Sc = pd.Series(txt.split('\n')).str.split(':').apply(pd.Series).rename(columns = {0:'vars', 1:'description'})#.set_index('vars').description

# %%
Sc.head()
# Out:
#                       vars  \
# 0  id_mutation
# 1      date_mutation
# 2      numero_disposition
# 3      valeur_fonciere
# 4      adresse_numero
#
#                                                         description
# 0   Identifiant de mutation (non stable, sert à grouper les lignes)
# 1   Date de la mutation au format ISO-8601 (YYYY-MM-DD)
# 2   Numéro de disposition
# 3   Valeur foncière (séparateur décimal = point)
# 4   Numéro de l'adresse

# %% [markdown]
# ## Selec colonnes

# %%
txt = '''Date mutation
Valeur fonciere
Code postal
Commune
Code departement
Code commune
Surface reelle bati
Nombre pieces principales
Surface terrain'''

# %%
s = pd.Series(txt.split('\n')).str.replace(' ','_')
s
# Out:
# 0    Date_mutation
# 1    Valeur_fonciere
# 2    Code_postal
# 3    Commune
# 4    Code_departement
# 5    Code_commune
# 6    Surface_reelle_bati
# 7    Nombre_pieces_principales
# 8    Surface_terrain
# dtype: object

# %%
df.columns
# Out:
# Index(['No_disposition', 'Date_mutation', 'Nature_mutation', 'Valeur_fonciere',
#        'No_voie', 'Type_de_voie', 'Code_voie', 'Voie', 'Code_postal',
#        'Commune', 'Code_departement', 'Code_commune', 'Section', 'No_plan',
#        '1er_lot', 'Nombre_de_lots', 'Code_type_local', 'Type_local',
#        'Surface_reelle_bati', 'Nombre_pieces_principales', 'Nature_culture',
#        'Surface_terrain'],
#       dtype='object')

# %%
s.isin(df.columns)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# dtype: bool

# %%
df = df[s.values]

# %%
df.shape
# Out:
# (1017154, 9)

# %%
df.to_pickle('df')

# %% [markdown]
# ## format data

# %%
df = pd.read_pickle('df')
df.shape
# Out:
# (1017154, 9)

# %%
df.head()
# Out:
#   Date_mutation Valeur_fonciere  Code_postal                     Commune  \
# 0  11/01/2019    84000,00        1960.0       PERONNAS
# 1  11/01/2019    84000,00        1960.0       PERONNAS
# 2  08/02/2019    210000,00       1250.0       MONTAGNAT
# 3  08/02/2019    210000,00       1250.0       MONTAGNAT
# 4  04/04/2019    36000,00        1560.0       SAINT-JULIEN-SUR-REYSSOUZE
#
#   Code_departement  Code_commune  Surface_reelle_bati  \
# 0  1                289           0.0
# 1  1                289           67.0
# 2  1                254           118.0
# 3  1                254           118.0
# 4  1                367           60.0
#
#    Nombre_pieces_principales  Surface_terrain
# 0  0.0                       NaN
# 1  3.0                       NaN
# 2  4.0                        913.0
# 3  4.0                        1000.0
# 4  3.0                        96.0

# %%
df.apply(np.dtype)
# Out:
# Date_mutation                object
# Valeur_fonciere              object
# Code_postal                  object
# Commune                      object
# Code_departement             object
# Code_commune                 object
# Surface_reelle_bati          object
# Nombre_pieces_principales    object
# Surface_terrain              object
# dtype: object

# %%
dftype = pd.DataFrame([df[c].apply(type).value_counts() for c in df.columns])

# %%
dftype
# Out:
#                            <class 'str'>  <class 'float'>  <class 'int'>
# Date_mutation              1017154.0     NaN              NaN
# Valeur_fonciere            1004369.0      12785.0         NaN
# Code_postal               NaN             1017154.0       NaN
# Commune                    1017154.0     NaN              NaN
# Code_departement           32768.0       NaN               984386.0
# Code_commune              NaN            NaN               1017154.0
# Surface_reelle_bati       NaN             1017154.0       NaN
# Nombre_pieces_principales NaN             1017154.0       NaN
# Surface_terrain           NaN             1017154.0       NaN

# %%
df.Valeur_fonciere = pd.to_numeric(df.Valeur_fonciere[df.Valeur_fonciere.apply(type) == str].str.split(',').str[0])

# %%
for c in df.columns.drop(['Date_mutation' , 'Commune']):
    df[c] = pd.to_numeric(df[c], errors='coerce')

# %%
df.head()
# Out:
#   Date_mutation  Valeur_fonciere  Code_postal                     Commune  \
# 0  11/01/2019    84000.0          1960.0       PERONNAS
# 1  11/01/2019    84000.0          1960.0       PERONNAS
# 2  08/02/2019    210000.0         1250.0       MONTAGNAT
# 3  08/02/2019    210000.0         1250.0       MONTAGNAT
# 4  04/04/2019    36000.0          1560.0       SAINT-JULIEN-SUR-REYSSOUZE
#
#    Code_departement  Code_commune  Surface_reelle_bati  \
# 0  1.0               289           0.0
# 1  1.0               289           67.0
# 2  1.0               254           118.0
# 3  1.0               254           118.0
# 4  1.0               367           60.0
#
#    Nombre_pieces_principales  Surface_terrain
# 0  0.0                       NaN
# 1  3.0                       NaN
# 2  4.0                        913.0
# 3  4.0                        1000.0
# 4  3.0                        96.0

# %% [markdown]
# df.Valeur_fonciere[df.Valeur_fonciere.apply(type) == str]

# %%
df.to_pickle('df')

# %% [markdown]
# ## Enrichissement II (merge): region

# %%
df = pd.read_pickle('df')
df.shape
# Out:
# (1017154, 9)

# %%
df.isnull().sum()
# Out:
# Date_mutation                0
# Valeur_fonciere              12785
# Code_postal                  12156
# Commune                      0
# Code_departement             1064
# Code_commune                 0
# Surface_reelle_bati          476539
# Nombre_pieces_principales    476539
# Surface_terrain              321571
# dtype: int64

# %%
df = df[df.Code_departement.notnull()]

# %%
df.head()
# Out:
#   Date_mutation  Valeur_fonciere  Code_postal                     Commune  \
# 0  11/01/2019    84000.0          1960.0       PERONNAS
# 1  11/01/2019    84000.0          1960.0       PERONNAS
# 2  08/02/2019    210000.0         1250.0       MONTAGNAT
# 3  08/02/2019    210000.0         1250.0       MONTAGNAT
# 4  04/04/2019    36000.0          1560.0       SAINT-JULIEN-SUR-REYSSOUZE
#
#    Code_departement  Code_commune  Surface_reelle_bati  \
# 0  1.0               289           0.0
# 1  1.0               289           67.0
# 2  1.0               254           118.0
# 3  1.0               254           118.0
# 4  1.0               367           60.0
#
#    Nombre_pieces_principales  Surface_terrain
# 0  0.0                       NaN
# 1  3.0                       NaN
# 2  4.0                        913.0
# 3  4.0                        1000.0
# 4  3.0                        96.0

# %% [markdown]
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&ved=2ahUKEwi3jL-HwurnAhVFzRoKHWklBVQQFjAAegQIAxAB&url=https%3A%2F%2Fwww.data.gouv.fr%2Ffr%2Fdatasets%2Fregions-departements-villes-et-villages-de-france-et-doutre-mer%2F&usg=AOvVaw3wxiIerUptdSJR6SOmfrX_

# %%
dfgeo = pd.read_csv('departements-france.csv')
dfgeo
dfgeo.shape
# Out:
#    code_departement          nom_departement  code_region  \
# 0   01               Ain                      84
# 1   02               Aisne                    32
# 2   03               Allier                   84
# 3   04               Alpes-de-Haute-Provence  93
# 4   05               Hautes-Alpes             93
# ..  ..                        ...             ..
# 95  971              Guadeloupe               1
# 96  972              Martinique               2
# 97  973              Guyane                   3
# 98  974              La Réunion               4
# 99  976              Mayotte                  6
#
#                     nom_region
# 0   Auvergne-Rhône-Alpes
# 1   Hauts-de-France
# 2   Auvergne-Rhône-Alpes
# 3   Provence-Alpes-Côte d'Azur
# 4   Provence-Alpes-Côte d'Azur
# ..                         ...
# 95  Guadeloupe
# 96  Martinique
# 97  Guyane
# 98  La Réunion
# 99  Mayotte
#
# [100 rows x 4 columns]
# (100, 4)

# %% [markdown]
# manque paris !!!!!

# %% [markdown]
# ### Ajout Paris

# %%
dfgeo.loc[100] = ['75', 'Paris', '11', 'Île-de-France']

# %%
dfgeo[dfgeo.nom_region == 'Île-de-France']
# Out:
#     code_departement    nom_departement code_region     nom_region
# 76   77               Seine-et-Marne     11          Île-de-France
# 77   78               Yvelines           11          Île-de-France
# 90   91               Essonne            11          Île-de-France
# 91   92               Hauts-de-Seine     11          Île-de-France
# 92   93               Seine-Saint-Denis  11          Île-de-France
# 93   94               Val-de-Marne       11          Île-de-France
# 94   95               Val-d'Oise         11          Île-de-France
# 100  75               Paris              11          Île-de-France

# %%
dfgeo.code_departement.nunique()
# Out:
# 101

# %% [markdown]
# ### correction Code_departement

# %% [markdown]
# les dep avec la valeur ,1,2 .... => 01, 02 ....

# %%
cd = df[df.Code_departement.notnull()].Code_departement.astype(int).astype(str).copy()

# %%
cd.apply(len).value_counts()
# Out:
# 2    954112
# 1    59330
# 3    2648
# Name: Code_departement, dtype: int64

# %% [markdown]
# cd = cd.astype(str)

# %%
mask = cd.apply(len)==1
cd[mask] = cd[mask].apply(lambda x : '0'+x)

# %%
df.loc[cd.index, 'Code_departement'] = cd

# %%
df.head()
# Out:
#   Date_mutation  Valeur_fonciere  Code_postal                     Commune  \
# 0  11/01/2019    84000.0          1960.0       PERONNAS
# 1  11/01/2019    84000.0          1960.0       PERONNAS
# 2  08/02/2019    210000.0         1250.0       MONTAGNAT
# 3  08/02/2019    210000.0         1250.0       MONTAGNAT
# 4  04/04/2019    36000.0          1560.0       SAINT-JULIEN-SUR-REYSSOUZE
#
#   Code_departement  Code_commune  Surface_reelle_bati  \
# 0  01               289           0.0
# 1  01               289           67.0
# 2  01               254           118.0
# 3  01               254           118.0
# 4  01               367           60.0
#
#    Nombre_pieces_principales  Surface_terrain
# 0  0.0                       NaN
# 1  3.0                       NaN
# 2  4.0                        913.0
# 3  4.0                        1000.0
# 4  3.0                        96.0

# %%
df['Region'] = df.Code_departement.map(dfgeo.set_index('code_departement')['nom_region'])
df['code_region'] = df.Code_departement.map(dfgeo.set_index('code_departement')['code_region'])

# %%
df[df.Region.isna()].Code_departement.value_counts()
# Out:
# Series([], Name: Code_departement, dtype: int64)

# %%
df.to_pickle('df')

# %% [markdown]
# # export data

# %%
df = pd.read_pickle('df')
df.shape
df.head(2)
# Out:
# (1016090, 11)
#   Date_mutation  Valeur_fonciere  Code_postal   Commune Code_departement  \
# 0  11/01/2019    84000.0          1960.0       PERONNAS  01
# 1  11/01/2019    84000.0          1960.0       PERONNAS  01
#
#    Code_commune  Surface_reelle_bati  Nombre_pieces_principales  \
# 0  289           0.0                  0.0
# 1  289           67.0                 3.0
#
#    Surface_terrain                Region code_region
# 0 NaN               Auvergne-Rhône-Alpes  84
# 1 NaN               Auvergne-Rhône-Alpes  84

# %%
data = df[df.Code_departement == '75'][['Valeur_fonciere' , 'Nombre_pieces_principales']]
data.shape
data.head(2)
# Out:
# (21371, 2)
#         Valeur_fonciere  Nombre_pieces_principales
# 995783  1196000.0        3.0
# 995784  1570490.0        0.0

# %% [markdown]
# ## json

# %%
params = ['split', 'records', 'index', 'columns', 'values', 'table']

# %%
for param in params:
    print (param)
    print (data[:10].to_json(orient=param))
    print ()
# Out:
# split
# {"columns":["Valeur_fonciere","Nombre_pieces_principales"],"index":[17980,17981,17982,17983,17984],"data":[[377240.0,0.0],[377240.0,1.0],[377240.0,1.0],[377240.0,2.0],[377240.0,1.0]]}
#
# records
# [{"Valeur_fonciere":377240.0,"Nombre_pieces_principales":0.0},{"Valeur_fonciere":377240.0,"Nombre_pieces_principales":1.0},{"Valeur_fonciere":377240.0,"Nombre_pieces_principales":1.0},{"Valeur_fonciere":377240.0,"Nombre_pieces_principales":2.0},{"Valeur_fonciere":377240.0,"Nombre_pieces_principales":1.0}]
#
# index
# {"17980":{"Valeur_fonciere":377240.0,"Nombre_pieces_principales":0.0},"17981":{"Valeur_fonciere":377240.0,"Nombre_pieces_principales":1.0},"17982":{"Valeur_fonciere":377240.0,"Nombre_pieces_principales":1.0},"17983":{"Valeur_fonciere":377240.0,"Nombre_pieces_principales":2.0},"17984":{"Valeur_fonciere":377240.0,"Nombre_pieces_principales":1.0}}
#
# columns
# ...

# %% [markdown]
# ## Clipboard

# %%
data.index.name = 'index'

# %%
data.sample(100).fillna(0).astype(int).to_clipboard(sep=',')

# %%
from IPython.display import display, HTML
display(HTML(df.head(2).to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date_mutation</th>
#       <th>Valeur_fonciere</th>
#       <th>Code_postal</th>
#       <th>Commune</th>
#       <th>Code_departement</th>
#       <th>Code_commune</th>
#       <th>Surface_reelle_bati</th>
#       <th>Nombre_pieces_principales</th>
#       <th>Surface_terrain</th>
#       <th>Region</th>
#       <th>code_region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>11/01/2019</td>
#       <td>84000.0</td>
#       <td>1960.0</td>
#       <td>PERONNAS</td>
#       <td>01</td>
#       <td>289</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>Auvergne-Rhône-Alpes</td>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11/01/2019</td>
#       <td>84000.0</td>
#       <td>1960.0</td>
#       <td>PERONNAS</td>
#       <td>01</td>
#       <td>289</td>
#       <td>67.0</td>
# ...

# %% [markdown]
# df.to_markdown()

# %% [markdown]
# ## Csv excel ...

# %% [markdown]
# ## ex : Row graph (~Maxx)

# %%
data.index.name = 'index'

# %%
data[:1000].fillna(0).astype(int).to_clipboard(sep=',')

# %% [markdown]
# upload file to
# https://app.rawgraphs.io/

# %%
from IPython.display import Image
Image("rowgraph.png", width=500)

# %% [markdown]
# # Analyse

# %%
df = pd.read_pickle('df')
df.shape
df.head(2)
# Out:
# (1016090, 11)
#   Date_mutation  Valeur_fonciere  Code_postal   Commune Code_departement  \
# 0  11/01/2019    84000.0          1960.0       PERONNAS  01
# 1  11/01/2019    84000.0          1960.0       PERONNAS  01
#
#    Code_commune  Surface_reelle_bati  Nombre_pieces_principales  \
# 0  289           0.0                  0.0
# 1  289           67.0                 3.0
#
#    Surface_terrain                Region code_region
# 0 NaN               Auvergne-Rhône-Alpes  84
# 1 NaN               Auvergne-Rhône-Alpes  84

# %%
df.nunique()
# Out:
# Date_mutation                179
# Valeur_fonciere              51658
# Code_postal                  5491
# Commune                      24398
# Code_departement             95
# Code_commune                 897
# Surface_reelle_bati          2490
# Nombre_pieces_principales    31
# Surface_terrain              28492
# Region                       16
# code_region                  17
# dtype: int64

# %% [markdown]
# ## Groupby

# %%
df = pd.read_pickle('df')
df.shape
df.head(2)
# Out:
# (1016090, 11)
#   Date_mutation  Valeur_fonciere  Code_postal   Commune Code_departement  \
# 0  11/01/2019    84000.0          1960.0       PERONNAS  01
# 1  11/01/2019    84000.0          1960.0       PERONNAS  01
#
#    Code_commune  Surface_reelle_bati  Nombre_pieces_principales  \
# 0  289           0.0                  0.0
# 1  289           67.0                 3.0
#
#    Surface_terrain                Region code_region
# 0 NaN               Auvergne-Rhône-Alpes  84
# 1 NaN               Auvergne-Rhône-Alpes  84

# %%
df.groupby('Region')['Valeur_fonciere'].mean().astype(int).plot.barh()

# %%
# Surface_terrain  > 100
df.groupby((df.Surface_terrain  > 100))['Valeur_fonciere'].mean().astype(int)
# Out:
# Surface_terrain
# False    600061
# True     1252150
# Name: Valeur_fonciere, dtype: int32

# %%
mask = (df.Surface_terrain  > 100).map({False : '< 100', True : '> 100'})
mask
# Out:
# 0          < 100
# 1          < 100
# 2          > 100
# 3          > 100
# 4          < 100
#            ...
# 1017149    > 100
# 1017150    > 100
# 1017151    > 100
# 1017152    > 100
# 1017153    > 100
# Name: Surface_terrain, Length: 1016090, dtype: object

# %%
df.groupby(mask)['Valeur_fonciere'].mean().astype(int)
# Out:
# Surface_terrain
# < 100    600061
# > 100    1252150
# Name: Valeur_fonciere, dtype: int32

# %%
#rappel base python = des listes partout
df.groupby(['Region' , mask])['Valeur_fonciere'].mean().astype(int).to_frame().head()
# Out:
#                                          Valeur_fonciere
# Region                  Surface_terrain
# Auvergne-Rhône-Alpes    < 100            379155
#                         > 100            783178
# Bourgogne-Franche-Comté < 100            106836
#                         > 100            112629
# Bretagne                < 100            284861

# %% [markdown]
# ## Describe

# %%
df.Valeur_fonciere.describe().astype(int)
# Out:
# count    1003305
# mean     983873
# std      7750284
# min      0
# 25%      56625
# 50%      144000
# 75%      258600
# max      1750000000
# Name: Valeur_fonciere, dtype: int32

# %%
df.groupby('Region')['Valeur_fonciere'].describe().astype(int).head()
# Out:
#                          count     mean       std  min    25%     50%     75%  \
# Region
# Auvergne-Rhône-Alpes     80543  604344   5643532   0    45000  135500  255000
# Bourgogne-Franche-Comté  34332  111546   214980    1    15000  62000   135000
# Bretagne                 66506  367836   12295913  1    45000  110000  192000
# Centre-Val de Loire      68977  1108839  6831860   1    42000  110000  200000
# Grand Est                53961  158899   430790    0    25000  84000   164000
#
#                                 max
# Region
# Auvergne-Rhône-Alpes     192346240
# Bourgogne-Franche-Comté  14443174
# Bretagne                 1750000000
# Centre-Val de Loire      54257152
# Grand Est                17100000

# %%
df.groupby('Region').nunique().head()
# Out:
#                          Date_mutation  Valeur_fonciere  Code_postal  Commune  \
# Region
# Auvergne-Rhône-Alpes     160            8958             709          2902
# Bourgogne-Franche-Comté  155            3083             373          2121
# Bretagne                 161            6889             321          1204
# Centre-Val de Loire      157            5751             237          1692
# Grand Est                153            5664             344          2740
#
#                          Code_departement  Code_commune  Surface_reelle_bati  \
# Region
# Auvergne-Rhône-Alpes     12                519           679
# Bourgogne-Franche-Comté  8                 637           445
# Bretagne                 4                 386           639
# Centre-Val de Loire      6                 414           684
# Grand Est                7                 654           644
#
#                          Nombre_pieces_principales  Surface_terrain  Region  \
# Region
# ...

# %% [markdown]
# ## Categories

# %%
pd.cut(df.Surface_reelle_bati, bins= [0,10,100,10000,100000]).value_counts().sort_index()
# Out:
# (0, 10]            2303
# (10, 100]          298806
# (100, 10000]       109925
# (10000, 100000]    183
# Name: Surface_reelle_bati, dtype: int64

# %%
a = pd.cut(df.Surface_reelle_bati, bins= [0,10,100,1000])
df.groupby([df.code_region, a]).size().head()
# Out:
# code_region  Surface_reelle_bati
# 1            (0, 10]                1
#              (10, 100]              39
#              (100, 1000]            8
# 2            (0, 10]                3
#              (10, 100]              494
# dtype: int64

# %% [markdown]
# ## stack unstack

# %%
a = pd.cut(df.Surface_reelle_bati, bins= [0,10,100,1000])
a = df.groupby([df.code_region, a]).size()
a.head()
# Out:
# code_region  Surface_reelle_bati
# 1            (0, 10]                1
#              (10, 100]              39
#              (100, 1000]            8
# 2            (0, 10]                3
#              (10, 100]              494
# dtype: int64

# %%
a.unstack().stack().unstack().fillna(0).astype(int).head()
# Out:
# Surface_reelle_bati  (0, 10]  (10, 100]  (100, 1000]
# code_region
# 1                    1        39         8
# 2                    3        494        124
# 3                    2        434        139
# 4                    0        138        38
# 11                   580      59092      14356

# %%
a.unstack().stack().unstack().fillna(0).astype(int).plot.bar(stacked = True)

# %% [markdown]
# ## pivot table

# %% [markdown]
# ## percentiles

# %%
df.Valeur_fonciere.quantile(0.1)
# Out:
# 9900.0

# %% [markdown]
# ## TimeSerie

# %%
df.head(2)
# Out:
#   Date_mutation  Valeur_fonciere  Code_postal   Commune Code_departement  \
# 0  11/01/2019    84000.0          1960.0       PERONNAS  01
# 1  11/01/2019    84000.0          1960.0       PERONNAS  01
#
#    Code_commune  Surface_reelle_bati  Nombre_pieces_principales  \
# 0  289           0.0                  0.0
# 1  289           67.0                 3.0
#
#    Surface_terrain                Region code_region
# 0 NaN               Auvergne-Rhône-Alpes  84
# 1 NaN               Auvergne-Rhône-Alpes  84

# %% [markdown]
# ### to Date time

# %%
df.Date_mutation.value_counts().sort_index()
# Out:
# 01/01/2019    203
# 01/02/2019    10662
# 01/03/2019    10700
# 01/04/2019    7870
# 01/05/2019    62
#               ..
# 30/05/2019    69
# 30/06/2019    7
# 31/01/2019    14044
# 31/03/2019    5
# 31/05/2019    3331
# Name: Date_mutation, Length: 179, dtype: int64

# %%
df['Date_mutation'] = pd.to_datetime(df['Date_mutation'])

# %% [markdown]
# ### Manip dt

# %%
df.Date_mutation.dt.month.value_counts().sort_index()
# Out:
# 1     159534
# 2     129188
# 3     158287
# 4     132550
# 5     130614
# 6     118738
# 7     36411
# 8     35106
# 9     22516
# 10    23593
# 11    37440
# 12    32113
# Name: Date_mutation, dtype: int64

# %%
grouped = df.groupby(df.Date_mutation.dt.month)
grouped.Valeur_fonciere.sum().plot()

# %%
grouped = df.groupby([df.Region, df.Date_mutation.dt.month])
grouped.Valeur_fonciere.sum().unstack(0)
# Out:
# Region         Auvergne-Rhône-Alpes  Bourgogne-Franche-Comté      Bretagne  \
# Date_mutation
# 1              1.692288e+10          827007458.0              7.664594e+09
# 2              1.501299e+10          467504948.0              7.264876e+09
# 3              5.118919e+09          438213765.0              2.606012e+09
# 4              2.592807e+09          588021455.0              2.167758e+09
# 5              3.325764e+09          497327528.0              1.391108e+09
# 6              2.415797e+09          384301112.0              1.217530e+09
# 7              8.161176e+08          107135957.0              3.413045e+08
# 8              6.215946e+08          155203578.0              3.196484e+08
# 9              3.077962e+08          92353223.0               2.346562e+08
# 10             3.686190e+08          78905784.0               2.514369e+08
# 11             7.062001e+08          104132968.0              6.806673e+08
# ...

# %%
grouped = df.groupby([df.Region, df.Date_mutation.dt.month])
grouped.Valeur_fonciere.sum().unstack(0).cumsum().plot(figsize = (20,5) )

# %% [markdown]
# ### rolling

# %%
dfparis = df[df.Region == 'Île-de-France']

# %%
dfparis.set_index('Date_mutation').Valeur_fonciere.plot()

# %%
a = dfparis.set_index('Date_mutation').sort_index()
a.Valeur_fonciere.rolling('7d').sum().plot()

# %% [markdown]
# # Export MAXX

# %% [markdown]
# ## lambda

# %% [markdown]
# ## function

# %% [markdown]
# ## swagger

# %% [markdown]
# ## widget

# %% [raw]
# On peut télécharger ce denier (environ 300mo) et avoir divers exercices listés ci-des
# sous:
# Transformation de fichier DVF à .CSV (où transformation par nos soins en amont ?
# Data Cleaning: on a X colonnes, on s'intéresse à seulement 9 d'entre elles:
# Exemple ici: Date mutation	Valeur fonciere	Code postal	Commune	Code departement	Code commune	Surface reelle bati	Nombre pieces principales	Surface terrain
#
#
# 3. On peut faire des exercices de grouping relativement basiques: par département et par commune (on a le code du département) et le code postal.
# 4. On peut enrichir ce fichier avec le concept de région (on crée ou on fait créer un fichier cartographiant les régions actuelles (ou anciennes, ou les deux) avec les départements. On demande de récupérer ce fichier et d'enrichir le présent (RegionMappingEnrichService si je devais parler en langage SG).
# 5. On peut même imaginer des recalcules de moyenne de valeur foncière par région avant et après la réforme (donc si on enlève ou ajoute des départements). Avec un calcul de variation, etc.
# 6. Introduction aux fonctions de bases : moyennes, time-series, min/max par axe, écart (variance) à la moyenne par rapport à un département/Région de base (exemple: écart du département Lorraine par rapport à Yvelines).
# 7. Travail sur les déciles, quartiles, "percentiles" (à 1%, 5% et 10%), etc.
# 8. Extrapolation linéaire sur un département selon la tendance des valeurs sur l'année à +3 mois.
# 9. Gros zoom sur le drill-down: demander d'agréger les chiffres niveau national et par région. Puis de produire un graphique. Puis d'introduire la notion de départements qui permettra par la suite de cliquer sur un élément de graph (imaginons un camembert) et d'avoir la décomposition de ladite région en départements. Cela fera le lien avec la structure analytique de la banque.

# %% [markdown]
# # Pycharm

# %% [markdown]
# ## presentation

# %% [markdown]
# ## export function to pycharm

# %% [markdown]
# # refactorer

# %% [markdown]
# ## class

# %% [markdown]
# ## module

# %% [markdown]
# ## TP

# %% [markdown]
# # dev

# %% [markdown]
# ## pytest

# %% [markdown]
# ## git

# %% [markdown]
# # Drill Down

# %% [markdown]
# # Bonus

# %% [markdown]
# ## Scrap ?

# %% [markdown]
# ## GeoLoc
